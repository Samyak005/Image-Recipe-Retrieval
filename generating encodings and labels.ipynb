# %%
# from resnet50 import ResNet50
import numpy as np 
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
resnet_model = ResNet50(weights='imagenet', include_top=False)

def extract_features(img_path):
  img = image.load_img(img_path, target_size=(224, 224))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)
  features = resnet_model.predict(x)
  return np.expand_dims(features.flatten(), axis=0)

# %%
num = 1000
count = 0
arr = np.empty((0,100352), int)
img_path = '../Recipe1M/recipe1M_images_test/test/'
file_path = './rec_imgID_test_new2.txt'
with open(file_path) as f:
	while(True):
		if(count >= num):
			break
        line = f.readline()
        img_name = line.split(' ')[0]
        # print(img_name)

        img_title = img_name.split('.')[0]
        # print(img_title)

        img_path_final = img_path
        for i in range(4):
            img_path_final = img_path_final + img_title[i] + '/'
        img_path_final = img_path_final + img_name
        arr = np.append(arr, extract_features(img_path_final), axis=0)
        # print('cp ' + img_path_final + ' V2-20000')
        # os.system('cp ' + img_path_final + ' V2-20000')
        count = count + 1
        print(count)
        # print(img_path_final)

from numpy import save
save('test_image_encoding_1000.npy', arr)
# Out:
# 3e233001e2.jpg
# 3e233001e2
# ../Recipe1M/recipe1M_images_test/3/e/2/3/3e233001e2.jpg

# %%
from numpy import savetxt
num = 1000
count = 0
arr = np.empty((0,100352), int)
img_path = '../Recipe1M/recipe1M_images_train/train/'
file_path = './rec_imgID_train_new2.txt'
with open(file_path) as f:
    while(True):
        if(count % num == 0):
            savetxt('train_image_encoding' + str(count) + '.csv', arr, delimiter=',')
            arr = np.empty((0,100352), int)
        line = f.readline()
        img_name = line.split(' ')[0]
        # print(img_name)

        img_title = img_name.split('.')[0]
        # print(img_title)

        img_path_final = img_path
        for i in range(4):
            img_path_final = img_path_final + img_title[i] + '/'
        img_path_final = img_path_final + img_name
        arr = np.append(arr, extract_features(img_path_final), axis=0)
        # print('cp ' + img_path_final + ' V2-20000')
        # os.system('cp ' + img_path_final + ' V2-20000')
        count = count + 1
        print(count)
        # print(img_path_final)
# Out:
# 1
# 20672
# 20673
# 20674
# 20675
# 20676
# 20677
# 20678
# 20679
# 20680
# 20681
# 20682
# 20683
# 20684
# 20685
# 20686
# 20687
# 20688
# 20689
# 20690
# 20691
# 20692
# 20693
# 20694
# 20695
# 20696
# 20697
# 20698
# 20699
# 20700
# 20701
# 20702
# 20703
# 20704
# 20705
# 20706
# 20707
# 20708
# 20709
# 20710
# 20711
# 20712
# 20713
# 20714
# 20715
# 20716
# 20717
# 20718
# 20719
# 20720
# 20721
# 20722
# 20723
# 20724
# 20725
# 20726
# 20727
# 20728
# 20729
# 20730
# 20731
# 20732
# 20733
# 20734
# 20735
# 20736
# 20737
# 20738
# 20739
# 20740
# 20741
# 20742
# 20743
# 20744
# 20745
# 20746
# 20747
# 20748
# 20749
# 20750
# 20751
# 20752
# 20753
# 20754
# 20755
# 20756
# 20757
# 20758
# 20759
# 20760
# 20761
# 20762
# 20763
# 20764
# 20765
# 20766
# 20767
# 20768
# 20769
# 20770
# 20771
# 20772
# 20773
# 20774
# 20775
# 20776
# 20777
# 20778
# 20779
# 20780
# 20781
# 20782
# 20783
# 20784
# 20785
# 20786
# 20787
# 20788
# 20789
# 20790
# 20791
# 20792
# 20793
# 20794
# 20795
# ...

# %%
from csv import reader
count = 0
num = 1
# open file in read mode
with open('train_image_encoding1000.csv', 'r') as read_obj:
    # pass the file object to reader() to get the reader object
    csv_reader = reader(read_obj)
    # Iterate over each row in the csv using reader object
    for row in csv_reader:
        # row variable is a list that represents a row in csv
        print(row)
        count = count + 1
        if count is num:
            break
# Out:
# 0e+00', '0.000000000000000000e+00', '2.611846923828125000e-01', '0.000000000000000000e+00', '4.034273624420166016e-01', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '4.368942737579345703e+00', '7.999535799026489258e-01', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '3.149492740631103516e-01', '7.391269207000732422e-01', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '3.740641593933105469e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '3.215534210205078125e+00', '0.000000000000000000e+00', '0.000000000000000000e+00', '0.0000000
# ...

# %%
num = 1000
count = 0
file_path = './rec_imgID_train_new2.txt'
with open(file_path) as f:
    out = open('train_label_999.txt', 'a')
    while(count<24000):
        if(count % num == 0):
            out.close()
            out = open('train_label_' + str(count+999) + '.txt', 'a')
        line = f.readline()
        
        out.write(line)
        count = count + 1

# %%
num = 1000
count = 0
file_path = './rec_imgID_test_new2.txt'
with open(file_path) as f:
    out = open('test_label_999.txt', 'a')
    while(count<1000):
        if(count % num == 0):
            out.close()
            out = open('test_label_' + str(count+999) + '.txt', 'a')
        line = f.readline()
        
        out.write(line)
        count = count + 1
    out.close()
